# %% [markdown]
# # 05 Orchestration Platform Audit
#
# This notebook explores the Airflow metadata and operational health of the platform.

# %%
import os
import sys
sys.path.append('../../src')
from orchestration.platform_utils import check_delta_freshness

silver_path = "../../data/iot/delta/silver"
is_fresh, age, latest = check_delta_freshness(silver_path)
print(f"Silver Freshness: {is_fresh}, Age: {age:.2f}m, Latest: {latest}")
