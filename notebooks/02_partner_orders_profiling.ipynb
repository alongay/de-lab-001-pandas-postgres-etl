# %% [markdown]
# # Explore Partner Orders
#
# This notebook demonstrates how to import your ETL extraction and transformation logic into a Jupyter notebook for interactive data profiling.
#
# We will load data from our configured partners (API and CSV).

# %%
import os
import pandas as pd

# Import module code (sys.path is pre-configured via Jupyter)
from src.extract_partner_api import extract_partner_api
from src.extract_partner_csv import extract_partner_csv
from src.transform_orders import transform_orders_dataframe

# %% [markdown]
# ## 1. Extract Raw Data

# %%
df_api = extract_partner_api()
df_csv = extract_partner_csv()
df_raw = pd.concat([df_api, df_csv], ignore_index=True)
df_raw.head()

# %% [markdown]
# ## 2. Transform the Data
#
# Applies static typing, schema coalescence from disparate sources, and field checks.

# %%
parsed = transform_orders_dataframe(df_raw)
df_clean = parsed.dataframe
df_clean.head()

# %% [markdown]
# ## 3. Data Profiling
#
# Let's look at missing values, summary statistics, and categorical distributions.

# %%
print("DataFrame Info:")
df_clean.info()

# %%
print("\n--- Null Value Counts ---")
df_clean.isna().sum()

# %%
print("\n--- Order Status Distribution ---")
df_clean['order_status'].value_counts(dropna=False)

# %%
print("\n--- Order Total Statistics ---")
df_clean['order_total'].describe()
